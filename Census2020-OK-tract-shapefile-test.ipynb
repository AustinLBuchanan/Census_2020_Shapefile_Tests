# %%
# Download file from:
# https://www2.census.gov/geo/tiger/TIGER2020/TRACT/

import geopandas as gpd

filepath = ''
filename = 'tl_2020_40_tract.shp'
df = gpd.read_file( filepath + filename )

# %%
my_fig = df.plot().get_figure()

# %%
for col in df.columns:
    print(col)
# Out:
# STATEFP
# COUNTYFP
# TRACTCE
# GEOID
# NAME
# NAMELSAD
# MTFCC
# FUNCSTAT
# ALAND
# AWATER
# INTPTLAT
# INTPTLON
# geometry

# %%
GEOIDs = df["GEOID"]
print(GEOIDs)
# Out:
# 0       40027201603
# 1       40109101500
# 2       40037021600
# 3       40037021000
# 4       40125500700
#            ...
# 1200    40061279100
# 1201    40033871100
# 1202    40033871200
# 1203    40131050105
# 1204    40061279300
# Name: GEOID, Length: 1205, dtype: object

# %%
for row in df.itertuples():
    if row.COUNTYFP == '119': # Payne county
        print(row.NAME)
# Out:
# 102.02
# 110.01
# 105.01
# 109.02
# 105.02
# 111.03
# 111.04
# 105.03
# 102.01
# 110.02
# 109.01
# 104
# 106
# 107
# 108
# 114
# 103
# 112
# 101.02
# 101.01
# 111.01
# 113.02
# 113.01
