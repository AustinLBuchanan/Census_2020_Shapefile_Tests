# %%
# download file from:
# https://www2.census.gov/geo/tiger/TIGER2020PL/LAYER/COUNTY/2020/

import geopandas as gpd

filepath = ''
filename = 'tl_2020_40_county20.shp'
df = gpd.read_file( filepath + filename )

# %%
my_fig = df.plot().get_figure()

# %%
for col in df.columns:
    print(col)
# Out:
# STATEFP20
# COUNTYFP20
# COUNTYNS20
# GEOID20
# NAME20
# NAMELSAD20
# LSAD20
# CLASSFP20
# MTFCC20
# CSAFP20
# CBSAFP20
# METDIVFP20
# FUNCSTAT20
# ALAND20
# AWATER20
# INTPTLAT20
# INTPTLON20
# geometry

# %%
GEOIDs = df["GEOID20"]
print(GEOIDs)
# Out:
# 0     40149
# 1     40065
# 2     40093
# 3     40041
# 4     40039
#       ...
# 72    40037
# 73    40125
# 74    40075
# 75    40085
# 76    40103
# Name: GEOID20, Length: 77, dtype: object

# %%
for row in df.itertuples():
    if row.NAME20 == 'Payne': 
        print(row)
# Out:
# Pandas(Index=42, STATEFP20='40', COUNTYFP20='119', COUNTYNS20='01101847', GEOID20='40119', NAME20='Payne', NAMELSAD20='Payne County', LSAD20='06', CLASSFP20='H1', MTFCC20='G4020', CSAFP20=None, CBSAFP20='44660', METDIVFP20=None, FUNCSTAT20='A', ALAND20=1773885850, AWATER20=31991880, INTPTLAT20='+36.0792253', INTPTLON20='-096.9752553', geometry=<shapely.geometry.polygon.Polygon object at 0x000002CE37B948C8>)
